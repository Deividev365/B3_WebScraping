# %% [markdown]
# # WebScrapping Application with Python
# ----

# %% [markdown]
# O objetivo do projeto é apresentar os conceitos básicos de Webscraping utilizando as principais bibliotecas hoje disponíveis no Python para realizar a consulta na base da infomoney para atualizarmos em uma tabela em tempo real as maiores altas e mínimas das ações na Bolsa de Valores.<br>
# <br>
# <li>Python</li>
# <li>Sellenium</li>
# <li>Pandas</li>
# <li>Jupyter Notebook</li>

# %% [markdown]
# <h3>Importing Libraries that will be used</h3>

# %%
from selenium import webdriver

# %%
from selenium.webdriver.chrome.service import Service

# %%
import pandas as pd

# %%
import os

# %% [markdown]
# <h3>Setting up url website and getting the chrome driver path</h3>

# %%
url = 'https://www.infomoney.com.br/ferramentas/altas-e-baixas/'

# %%
path = os.getcwd()

# %%
driver_service = Service(executable_path="C:/chromedriver.exe")

# %%
browser = webdriver.Chrome(service = driver_service)
browser.get(url)

# %% [markdown]
# <h3>Setting up Sellenium to find html element on the screen</h3>

# %%
highestStocks = browser.find_element("xpath",'//*[@id="altas_e_baixas"]')

# %%
highestStocks = browser.find_element("xpath",'//*[@id="altas_e_baixas"]/thead/tr/th[4]')

# %%
highest = browser.find_element("xpath",'//*[@id="altas_e_baixas"]').get_attribute('outerHTML')

# %% [markdown]
# <h2>Present the data into a table, using Pandas dataframe where dynamically change it when refreshed</h2>
#
# ---

# %% [markdown]
# <p>Var.Dia (%) - Maiores altas dentro de um período das ações, apresentado em uma tabela dinâmica</p>
# <br>

# %%
dataframe = pd.read_html(highest, decimal = ',', thousands = '.')
dataframe[0]
# Out:
#     Ativo   Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   ECOR3  18/01         4.60          5.02           2.91          3.37
# 1   CMIN3  18/01         4.74          4.40           3.49         16.18
# 2   RENT3  18/01        57.95          4.24           7.89          8.93
# 3   RRRP3  18/01        46.05          3.95           4.16         21.99
# 4   EZTC3  18/01        13.60          3.81           3.03          1.27
# ..    ...    ...          ...           ...            ...           ...
# 77  SUZB3  18/01        49.86         -2.65          -1.13          3.36
# 78  CVCB3  18/01         4.18         -3.24          -9.13         -6.90
# 79  MGLU3  18/01         3.56         -6.06           3.79         29.93
# 80  VIIA3  18/01         2.38         -6.66           0.42         -0.83
# 81  AMER3  18/01         1.74         -8.42         -44.76        -81.97
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume
# ...

# %%
lowestStocks = browser.find_element("xpath",'//*[@id="altas_e_baixas"]')

# %%
lowestStocks = browser.find_element("xpath",'//*[@id="altas_e_baixas"]/thead/tr/th[4]').click()

# %%
lowest = browser.find_element("xpath",'//*[@id="altas_e_baixas"]').get_attribute('outerHTML')

# %% [markdown]
# <p>Var.Dia (%) - Maiores Baixas dentro de um período das ações, apresentado em uma tabela dinâmica</p>
# <br>

# %%
dataframe = pd.read_html(lowest, decimal = ',', thousands = '.')
dataframe[0]
# Out:
#     Ativo   Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   AMER3  18/01         1.74         -8.42         -44.76        -81.97
# 1   VIIA3  18/01         2.38         -6.66           0.42         -0.83
# 2   MGLU3  18/01         3.56         -6.06           3.79         29.93
# 3   CVCB3  18/01         4.18         -3.24          -9.13         -6.90
# 4   SUZB3  18/01        49.86         -2.65          -1.13          3.36
# ..    ...    ...          ...           ...            ...           ...
# 77  EZTC3  18/01        13.60          3.81           3.03          1.27
# 78  RRRP3  18/01        46.05          3.95           4.16         21.99
# 79  RENT3  18/01        57.95          4.24           7.89          8.93
# 80  CMIN3  18/01         4.74          4.40           3.49         16.18
# 81  ECOR3  18/01         4.60          5.02           2.91          3.37
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume
# ...
